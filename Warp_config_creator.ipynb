# %% [markdown]
# <a href="https://colab.research.google.com/github/BarkBarklington/BarkBarklington.github.io/blob/main/Warp_config_creator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ================================
#@title Auto WGCF (Cloudflare WARP) Setup
#@markdown Just run script and it will auto generate
# ================================

# Download WGCF 2.2.29
# !wget -O wgcf https://github.com/ViRb3/wgcf/releases/download/v2.2.29/wgcf_2.2.29_linux_amd64
# !chmod +x wgcf

# Register automatically (no manual input)
# !echo | ./wgcf register

# Generate WireGuard config
# !./wgcf generate

# Download to your machine
from google.colab import files
files.download("wgcf-profile.conf")
# Out:
# --2025-11-14 12:53:17--  https://github.com/ViRb3/wgcf/releases/download/v2.2.29/wgcf_2.2.29_linux_amd64
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...
